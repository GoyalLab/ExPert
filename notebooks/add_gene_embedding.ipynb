# %%
import os
import scanpy as sc

os.chdir('../')
import logging

logging.basicConfig(
    level=logging.INFO,  # or DEBUG, WARNING, etc.
    format='%(asctime)s [%(levelname)s] %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
# Set path to gene embedding and meta set
emb_p = 'resources/gene_embeddings/GenePT_emebdding_v2/GenePT_gene_protein_embedding_model_3_text.pickle'
adata_p = '/home/xlv0877/proj_home/dl/data/merge/e9e6d0ef10839c41/perturb_metaset.h5ad'
adata = sc.read(adata_p)

# %%
from src.cls_embedding import EmbeddingProcessor

ep = EmbeddingProcessor(emb_p)

# %%
# Add gene embedding to adata
ep.process(adata)

# %%
# Check out added embedding
adata.uns['cls_embedding']
# Out:
#                 dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# neg;WDR4     0.002156 -0.018985  0.013023 -0.018269  0.015898 -0.012632
# neg;PSMB6   -0.030521 -0.003237  0.015758 -0.032362 -0.015609  0.014092
# neg;CHMP7    0.002995 -0.004284  0.018019  0.035930  0.014709  0.003569
# neg;ANAPC13  0.017699 -0.028894  0.018756 -0.001244  0.036455 -0.005664
# neg;HNRNPK  -0.008279  0.002519  0.012355  0.002285  0.006730  0.016461
# ...               ...       ...       ...       ...       ...       ...
# neg;TRAIP    0.026119  0.005245  0.011228  0.003344  0.009416 -0.005917
# neg;RPLP1    0.026520 -0.001120  0.014522 -0.030365  0.037128  0.021031
# neg;POP5     0.016792 -0.028081  0.023806 -0.013848  0.011506 -0.016370
# neg;LEO1     0.041350 -0.039639  0.015642  0.017517  0.029270 -0.018435
# neg;ADAM10   0.019949 -0.009062  0.013490  0.017792  0.006417  0.004617
#
#                 dim_6     dim_7     dim_8     dim_9  ...  dim_3062  dim_3063  \
# neg;WDR4    -0.028218  0.013805 -0.029199 -0.030312  ...  0.007200  0.001865
# neg;PSMB6   -0.003167  0.017524 -0.026168 -0.018656  ...  0.001623 -0.016865
# neg;CHMP7   -0.000075  0.006859 -0.000025 -0.027002  ... -0.005349 -0.016025
# neg;ANAPC13 -0.012451  0.006533  0.001945 -0.020937  ...  0.003430 -0.015809
# neg;HNRNPK  -0.011778  0.025220  0.006463 -0.013084  ...  0.016327 -0.018939
# ...               ...       ...       ...       ...  ...       ...       ...
# neg;TRAIP   -0.004942  0.026574 -0.023770 -0.001047  ...  0.003205 -0.004449
# neg;RPLP1   -0.039560  0.023625 -0.021332 -0.024366  ... -0.031407 -0.016607
# neg;POP5    -0.021707  0.023063  0.000623  0.015333  ... -0.020094 -0.020939
# neg;LEO1    -0.013918  0.012886  0.019857 -0.003895  ... -0.003281  0.010086
# neg;ADAM10  -0.003621  0.032954 -0.028717 -0.012686  ...  0.012489 -0.029074
#
#              dim_3064  dim_3065  dim_3066  dim_3067  dim_3068  dim_3069  \
# neg;WDR4    -0.022098 -0.000249  0.003766 -0.031504 -0.005263 -0.009287
# neg;PSMB6    0.001950  0.009925 -0.003029  0.010653 -0.014975 -0.011735
# neg;CHMP7   -0.029906  0.002537  0.010109 -0.018820 -0.016934  0.004054
# neg;ANAPC13 -0.021876  0.020792 -0.009523  0.005238 -0.013013  0.005462
# neg;HNRNPK  -0.020312  0.029058  0.005670  0.006414 -0.029933  0.003906
# ...               ...       ...       ...       ...       ...       ...
# neg;TRAIP   -0.036829  0.014701 -0.029605 -0.021067 -0.027458  0.007736
# neg;RPLP1   -0.012171  0.022803 -0.015414 -0.006178 -0.011917  0.009016
# neg;POP5     0.010348  0.021144  0.012242  0.014539 -0.018456 -0.005644
# neg;LEO1    -0.018850  0.016346 -0.009966 -0.023456 -0.008129 -0.011464
# neg;ADAM10  -0.019195  0.003564 -0.003382  0.000556 -0.015673  0.003941
#
#              dim_3070  dim_3071
# neg;WDR4     0.009717  0.002918
# neg;PSMB6    0.018619  0.003190
# neg;CHMP7    0.004691  0.009851
# neg;ANAPC13  0.015994 -0.014474
# neg;HNRNPK  -0.006906  0.006639
# ...               ...       ...
# neg;TRAIP    0.005905 -0.012264
# neg;RPLP1    0.000014 -0.007933
# neg;POP5     0.004003  0.009298
# neg;LEO1     0.012653 -0.008431
# neg;ADAM10   0.018889  0.025947
#
# [2374 rows x 3072 columns]

# %%
# Save updated adata to file
o = os.path.join(os.path.dirname(adata_p), f"{os.path.basename(adata_p).rstrip('.h5ad')}_w_prot_emb.h5ad")
adata.write_h5ad(o, compression='gzip')
# Out:
# ... storing 'perturbation_direction' as categorical

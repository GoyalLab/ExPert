# %%
import os

os.chdir('../')
import logging

logging.basicConfig(
    level=logging.INFO,  # or DEBUG, WARNING, etc.
    format='%(asctime)s [%(levelname)s] %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
# Set path to gene embedding and meta set
emb_p = 'resources/gene_embeddings/GenePT_emebdding_v2/GenePT_gene_protein_embedding_model_3_text.pickle'
adata_p = '/home/xlv0877/proj_home/dl/perturb-seq/data/raw/NormanWeissman2019_filtered.h5ad'

# %%
import scanpy as sc
# Read adata
adata = sc.read(adata_p)
# Out:
# 2025-07-02 15:10:30 [INFO] Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2025-07-02 15:10:30 [INFO] NumExpr defaulting to 16 threads.
# /home/xlv0877/.local/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/xlv0877/.local/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/xlv0877/.local/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from src.cls_embedding import EmbeddingProcessor

ep = EmbeddingProcessor(emb_p)

# %%
# Add gene embedding to adata
ep.process(adata)
# Out:
# 2025-07-02 15:11:11 [INFO] Reading embedding.
# 2025-07-02 15:11:45 [INFO] Filtering embedding for perturbed genes (237).
# 2025-07-02 15:11:45 [INFO] Found 105/237 perturbations in resource
# 2025-07-02 15:11:45 [INFO] Adding embedding to adata.

# %%
# Check out added embedding
adata.uns['cls_embedding']
# Out:
#                dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# neg;HOXA13  0.025532 -0.061109  0.008124  0.012137  0.013664 -0.009612
# neg;FOXL2   0.014225 -0.034194  0.011804 -0.004623 -0.020667  0.002908
# neg;POU3F2 -0.011243  0.004307  0.015254  0.019067  0.001284 -0.000937
# neg;CBL    -0.012812  0.024348  0.009925 -0.028970  0.003922 -0.001028
# neg;KIF2C  -0.000593  0.003716  0.013440  0.004711  0.021685  0.020346
# ...              ...       ...       ...       ...       ...       ...
# neg;MAP2K6 -0.026741 -0.016793  0.003523 -0.000967 -0.028060 -0.016869
# neg;AHR     0.009770 -0.003907 -0.001088  0.004121  0.009009  0.006784
# neg;MEIS1  -0.010969 -0.068260  0.010005  0.001538  0.028189 -0.019714
# neg;PTPN13  0.047993 -0.020206  0.012506  0.000367 -0.002039  0.002682
# neg;IKZF3  -0.007276 -0.007694  0.013202 -0.020226  0.034754 -0.019845
#
#                dim_6     dim_7     dim_8     dim_9  ...  dim_3062  dim_3063  \
# ...

# %%
# Save updated adata to file
o = '/home/xlv0877/proj_home/dl/data/test.h5ad'
adata.write_h5ad(o)
# Out:
# ... storing 'perturbation_direction' as categorical

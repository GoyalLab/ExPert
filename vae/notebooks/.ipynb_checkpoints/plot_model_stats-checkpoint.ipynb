# %%
import os
os.chdir('../')
# enable auto-reload of sources
# %load_ext autoreload
# %autoreload 2
# import tensorboard backend
from tensorboard.backend.event_processing import event_accumulator

# %%
# set log dir of harmonized model
log_dir = 'logs/harm/lightning_logs/version_5/'

# %%
# Load the event accumulator
event_acc = event_accumulator.EventAccumulator(log_dir)
event_acc.Reload()

# Check available tags (e.g., scalars, histograms, images)
tags = event_acc.Tags()
print(tags)
# Out:
# {'images': ['validation_confusion_matrix'], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'train_class_0_acc', 'train_class_1_acc', 'train_class_2_acc', 'train_class_3_acc', 'train_class_4_acc', 'train_precision', 'train_recall', 'train_f1', 'train_loss', 'train_recon_loss', 'train_kl_loss', 'train_kl_loss_pert', 'train_cell_type_loss', 'train_pert_type_loss', 'train_pert_loss', 'train_cell_type_acc', 'train_pert_acc', 'train_class_loss', 'epoch', 'val_class_0_acc', 'val_class_1_acc', 'val_class_2_acc', 'val_class_3_acc', 'val_class_4_acc', 'val_precision', 'val_recall', 'val_f1', 'val_loss', 'val_recon_loss', 'val_kl_loss', 'val_kl_loss_pert', 'val_cell_type_loss', 'val_pert_type_loss', 'val_pert_loss', 'val_cell_type_acc', 'val_pert_acc', 'val_class_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
import pandas as pd

results = []
tags = [t for t in tags['scalars'] if t != 'hp_metric']
for tag in tags:
    scalar_data = event_acc.Scalars(tag)
    # Extract the step and value from the scalar data
    steps = [entry.step for entry in scalar_data]
    values = [entry.value for entry in scalar_data]
    # Store the data in the dictionary
    results.append(pd.DataFrame({'tag': tag, 'step': steps, 'value': values}))

results = pd.concat(results)

# %%
# Out:
# 0     precision
# 1     precision
# 2     precision
# 3     precision
# 4     precision
#         ...
# 33     pert acc
# 34     pert acc
# 35     pert acc
# 36     pert acc
# 37     pert acc
# Name: tag, Length: 152, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_metrics(data, mode='train', targets=['cell_type_acc', 'pert_acc', 'precision', 'recall']):
    targets = [f'{mode}_{t}' for t in targets]
    df = data[data.tag.isin(targets)].copy()
    df.tag = df.tag.str.split('_').str[1:].str.join(' ')
    # plot 
    fig, ax = plt.subplots()
    ax = sns.lineplot(df, x='step', y='value', hue='tag', palette='Set1')
    plt.title(f'{mode.capitalize()} Metrics')
    plt.xlabel('Steps')
    plt.ylabel('Value')
    plt.show()

# %%
plot_metrics

# %%
# Extract scalar data (e.g., loss, accuracy)
# For example, extracting training loss data:
train_cell_type_acc = event_acc.Scalars('train_cell_type_acc')
train_pert_acc = event_acc.Scalars('train_pert_acc')
train_precision = event_acc.Scalars('train_precision')

# Display first 5 entries for training loss
for data in train_pert_acc[-5:]:
    print(data)
# Out:
# ScalarEvent(wall_time=1733718713.2559462, step=1699, value=0.53515625)
# ScalarEvent(wall_time=1733718720.706199, step=1749, value=0.5546875)
# ScalarEvent(wall_time=1733718728.3927493, step=1799, value=0.60546875)
# ScalarEvent(wall_time=1733718736.478604, step=1849, value=0.58984375)
# ScalarEvent(wall_time=1733718744.0044343, step=1899, value=0.578125)

# %%
data.value
# Out:
# 0.578125
